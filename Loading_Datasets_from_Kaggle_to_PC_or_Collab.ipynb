# %% [markdown]
# Author : Manish Bendale

# %%
# install the Kaggle client library for python.
# !pip install -q kaggle

# %%
# Run this cell and select the kaggle.json file downloaded
# from the Kaggle account settings page.
from google.colab import files
files.upload()

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/

# %%
# This permissions change avoids a warning on Kaggle tool startup.
# !chmod 600 ~/.kaggle/kaggle.json

# %%
pwd
# Out:
# '/content'

# %%
# Creating directory and changing the current working directory
# !mkdir Kaggle_dataset
# %cd Kaggle_dataset
# Out:
# /content/Kaggle_dataset

# %%
# Searching for dataset
# !kaggle datasets list -s flower-image-dataset
# Out:
# ref                                                   title                                      size  lastUpdated          downloadCount  voteCount  usabilityRating
# ----------------------------------------------------  ----------------------------------------  -----  -------------------  -------------  ---------  ---------------
# aksha05/flower-image-dataset                          Flower Image Dataset                      363MB  2020-05-08 12:11:01           2730         37  0.9375
# imsparsh/flowers-dataset                              Flowers Dataset                           205MB  2021-02-19 21:41:06           4122         43  0.9411765
# nunenuh/pytorch-challange-flower-dataset              Oxford 102 Flower Dataset                 330MB  2021-05-26 02:30:52           2919         27  0.7058824
# thanatoz/flower-classification-dataset                Flower_classification_dataset             815MB  2020-09-18 06:10:35            879         25  0.7058824
# ...

# %%
# Downloading dataset and coming out of directory
# !kaggle datasets download aksha05/flower-image-dataset
# %cd ..
# Out:
# ...
#  99% 361M/363M [00:17<00:00, 23.3MB/s]
# 100% 363M/363M [00:18<00:00, 21.1MB/s]
# /content

# %%
# Unzipping downloaded file and removing unusable file
# !unzip Kaggle_dataset/flower-image-dataset.zip -d Kaggle_dataset
# Out:
# Archive:  Kaggle_dataset/flower-image-dataset.zip
#   inflating: Kaggle_dataset/flowers/bougainvillea_00002.jpg
#   inflating: Kaggle_dataset/flowers/bougainvillea_00003.jpg
#   inflating: Kaggle_dataset/flowers/bougainvillea_00004.jpg
#   inflating: Kaggle_dataset/flowers/bougainvillea_00005.jpg
#   inflating: Kaggle_dataset/flowers/bougainvillea_00006.jpg
#   inflating: Kaggle_dataset/flowers/bougainvillea_00007.jpg
#   inflating: Kaggle_dataset/flowers/bougainvillea_00008.jpg
#   inflating: Kaggle_dataset/flowers/bougainvillea_00009.jpg
#   inflating: Kaggle_dataset/flowers/bougainvillea_00010.jpg
#   inflating: Kaggle_dataset/flowers/bougainvillea_00012.jpg
#   inflating: Kaggle_dataset/flowers/bougainvillea_00013.jpg
#   inflating: Kaggle_dataset/flowers/bougainvillea_00014.jpg
#   inflating: Kaggle_dataset/flowers/bougainvillea_00015.jpg
#   inflating: Kaggle_dataset/flowers/bougainvillea_00016.jpg
#   inflating: Kaggle_dataset/flowers/bougainvillea_00017.jpg
# ...

# %%
#!rm Kaggle_dataset/flower-image-dataset.zip
#!rm Kaggle_dataset/sample_submission.csv
